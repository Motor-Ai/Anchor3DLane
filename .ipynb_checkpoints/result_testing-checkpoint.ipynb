# %%
# %load_ext autoreload
# %autoreload 2

import torch
from testing.infer import *
import os
from mmcv.utils import Config, DictAction, get_git_hash
from mmseg.models import build_lanedetector
from mmengine.model import revert_sync_batchnorm
from mmseg.datasets import build_dataloader, build_dataset
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
cfg = Config.fromfile("/home/ec2-user/vardeep_ws/Anchor3DLane/configs/test_config.py")

model = build_lanedetector(cfg.model)

model.init_weights()

model = revert_sync_batchnorm(model)

dataset = build_dataset(cfg.data.test)

loader_cfg = dict(
    # cfg.gpus will be ignored if distributed
    num_gpus=1,
    dist=False,
    # seed=cfg.seed,
    drop_last=True,
    shuffle=cfg.data_shuffle,
    persistent_workers=False)
# The overall dataloader settings
loader_cfg.update({
    k: v
    for k, v in cfg.data.items() if k not in [
        'train', 'val', 'test', 'train_dataloader', 'val_dataloader',
        'test_dataloader'
    ]
})
checkpoint = torch.load("/home/ec2-user/vardeep_ws/Anchor3DLane/work_dir/openlane.pth")
model.load_state_dict(checkpoint['state_dict'])
# Out:
# 2024-05-02 09:28:08,695 - mmcv - INFO - initialize ResNetV1c with init_cfg [{'type': 'Kaiming', 'layer': 'Conv2d'}, {'type': 'Constant', 'val': 1, 'layer': ['_BatchNorm', 'GroupNorm']}]
# 2024-05-02 09:28:08,777 - mmcv - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2024-05-02 09:28:08,778 - mmcv - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2024-05-02 09:28:08,780 - mmcv - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2024-05-02 09:28:08,782 - mmcv - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2024-05-02 09:28:08,784 - mmcv - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2024-05-02 09:28:08,786 - mmcv - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2024-05-02 09:28:08,788 - mmcv - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2024-05-02 09:28:08,790 - mmcv - INFO - initialize BasicBlock with init_cfg {'type': 'Constant', 'val': 0, 'override': {'name': 'norm2'}}
# 2024-05-02 09:28:08,798 - mmcv - INFO -
# backbone.stem.0.weight - torch.Size([32, 3, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,798 - mmcv - INFO -
# backbone.stem.1.weight - torch.Size([32]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,799 - mmcv - INFO -
# backbone.stem.1.bias - torch.Size([32]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,799 - mmcv - INFO -
# backbone.stem.3.weight - torch.Size([32, 32, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,800 - mmcv - INFO -
# backbone.stem.4.weight - torch.Size([32]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,800 - mmcv - INFO -
# backbone.stem.4.bias - torch.Size([32]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,801 - mmcv - INFO -
# backbone.stem.6.weight - torch.Size([64, 32, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,801 - mmcv - INFO -
# backbone.stem.7.weight - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,802 - mmcv - INFO -
# backbone.stem.7.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,802 - mmcv - INFO -
# backbone.layer1.0.conv1.weight - torch.Size([64, 64, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,802 - mmcv - INFO -
# backbone.layer1.0.bn1.weight - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,803 - mmcv - INFO -
# backbone.layer1.0.bn1.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,803 - mmcv - INFO -
# backbone.layer1.0.conv2.weight - torch.Size([64, 64, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,804 - mmcv - INFO -
# backbone.layer1.0.bn2.weight - torch.Size([64]):
# ConstantInit: val=0, bias=0
#
# 2024-05-02 09:28:08,804 - mmcv - INFO -
# backbone.layer1.0.bn2.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
# anchor: 4431
# 2024-05-02 09:28:08,805 - mmcv - INFO -
# backbone.layer1.1.conv1.weight - torch.Size([64, 64, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,805 - mmcv - INFO -
# backbone.layer1.1.bn1.weight - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,806 - mmcv - INFO -
# backbone.layer1.1.bn1.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,806 - mmcv - INFO -
# backbone.layer1.1.conv2.weight - torch.Size([64, 64, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,807 - mmcv - INFO -
# backbone.layer1.1.bn2.weight - torch.Size([64]):
# ConstantInit: val=0, bias=0
#
# 2024-05-02 09:28:08,807 - mmcv - INFO -
# backbone.layer1.1.bn2.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,807 - mmcv - INFO -
# backbone.layer2.0.conv1.weight - torch.Size([128, 64, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,808 - mmcv - INFO -
# backbone.layer2.0.bn1.weight - torch.Size([128]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,808 - mmcv - INFO -
# backbone.layer2.0.bn1.bias - torch.Size([128]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,809 - mmcv - INFO -
# backbone.layer2.0.conv2.weight - torch.Size([128, 128, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,809 - mmcv - INFO -
# backbone.layer2.0.bn2.weight - torch.Size([128]):
# ConstantInit: val=0, bias=0
#
# 2024-05-02 09:28:08,810 - mmcv - INFO -
# backbone.layer2.0.bn2.bias - torch.Size([128]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,810 - mmcv - INFO -
# backbone.layer2.0.downsample.0.weight - torch.Size([128, 64, 1, 1]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,810 - mmcv - INFO -
# backbone.layer2.0.downsample.1.weight - torch.Size([128]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,813 - mmcv - INFO -
# backbone.layer2.0.downsample.1.bias - torch.Size([128]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,814 - mmcv - INFO -
# backbone.layer2.1.conv1.weight - torch.Size([128, 128, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,814 - mmcv - INFO -
# backbone.layer2.1.bn1.weight - torch.Size([128]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,814 - mmcv - INFO -
# backbone.layer2.1.bn1.bias - torch.Size([128]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,815 - mmcv - INFO -
# backbone.layer2.1.conv2.weight - torch.Size([128, 128, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,815 - mmcv - INFO -
# backbone.layer2.1.bn2.weight - torch.Size([128]):
# ConstantInit: val=0, bias=0
#
# 2024-05-02 09:28:08,816 - mmcv - INFO -
# backbone.layer2.1.bn2.bias - torch.Size([128]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,817 - mmcv - INFO -
# backbone.layer3.0.conv1.weight - torch.Size([256, 128, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,817 - mmcv - INFO -
# backbone.layer3.0.bn1.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,818 - mmcv - INFO -
# backbone.layer3.0.bn1.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,818 - mmcv - INFO -
# backbone.layer3.0.conv2.weight - torch.Size([256, 256, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,818 - mmcv - INFO -
# backbone.layer3.0.bn2.weight - torch.Size([256]):
# ConstantInit: val=0, bias=0
#
# 2024-05-02 09:28:08,819 - mmcv - INFO -
# backbone.layer3.0.bn2.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,819 - mmcv - INFO -
# backbone.layer3.0.downsample.0.weight - torch.Size([256, 128, 1, 1]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,820 - mmcv - INFO -
# backbone.layer3.0.downsample.1.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,820 - mmcv - INFO -
# backbone.layer3.0.downsample.1.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,820 - mmcv - INFO -
# backbone.layer3.1.conv1.weight - torch.Size([256, 256, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,821 - mmcv - INFO -
# backbone.layer3.1.bn1.weight - torch.Size([256]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,821 - mmcv - INFO -
# backbone.layer3.1.bn1.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,822 - mmcv - INFO -
# backbone.layer3.1.conv2.weight - torch.Size([256, 256, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,823 - mmcv - INFO -
# backbone.layer3.1.bn2.weight - torch.Size([256]):
# ConstantInit: val=0, bias=0
#
# 2024-05-02 09:28:08,824 - mmcv - INFO -
# backbone.layer3.1.bn2.bias - torch.Size([256]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,824 - mmcv - INFO -
# backbone.layer4.0.conv1.weight - torch.Size([512, 256, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,824 - mmcv - INFO -
# backbone.layer4.0.bn1.weight - torch.Size([512]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,825 - mmcv - INFO -
# backbone.layer4.0.bn1.bias - torch.Size([512]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,825 - mmcv - INFO -
# backbone.layer4.0.conv2.weight - torch.Size([512, 512, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,826 - mmcv - INFO -
# backbone.layer4.0.bn2.weight - torch.Size([512]):
# ConstantInit: val=0, bias=0
#
# 2024-05-02 09:28:08,826 - mmcv - INFO -
# backbone.layer4.0.bn2.bias - torch.Size([512]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,827 - mmcv - INFO -
# backbone.layer4.0.downsample.0.weight - torch.Size([512, 256, 1, 1]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,827 - mmcv - INFO -
# backbone.layer4.0.downsample.1.weight - torch.Size([512]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,827 - mmcv - INFO -
# backbone.layer4.0.downsample.1.bias - torch.Size([512]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,828 - mmcv - INFO -
# backbone.layer4.1.conv1.weight - torch.Size([512, 512, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,828 - mmcv - INFO -
# backbone.layer4.1.bn1.weight - torch.Size([512]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,829 - mmcv - INFO -
# backbone.layer4.1.bn1.bias - torch.Size([512]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
# 2024-05-02 09:28:08,829 - mmcv - INFO -
# backbone.layer4.1.conv2.weight - torch.Size([512, 512, 3, 3]):
# KaimingInit: a=0, mode=fan_out, nonlinearity=relu, distribution =normal, bias=0
#
# 2024-05-02 09:28:08,829 - mmcv - INFO -
# backbone.layer4.1.bn2.weight - torch.Size([512]):
# ConstantInit: val=0, bias=0
#
# 2024-05-02 09:28:08,830 - mmcv - INFO -
# backbone.layer4.1.bn2.bias - torch.Size([512]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,830 - mmcv - INFO -
# input_proj.weight - torch.Size([64, 512, 1, 1]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,832 - mmcv - INFO -
# input_proj.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,833 - mmcv - INFO -
# transformer_layer.self_attn.in_proj_weight - torch.Size([192, 64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,833 - mmcv - INFO -
# transformer_layer.self_attn.in_proj_bias - torch.Size([192]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,834 - mmcv - INFO -
# transformer_layer.self_attn.out_proj.weight - torch.Size([64, 64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,834 - mmcv - INFO -
# transformer_layer.self_attn.out_proj.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,834 - mmcv - INFO -
# transformer_layer.linear1.weight - torch.Size([128, 64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,835 - mmcv - INFO -
# transformer_layer.linear1.bias - torch.Size([128]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,836 - mmcv - INFO -
# transformer_layer.linear2.weight - torch.Size([64, 128]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,836 - mmcv - INFO -
# transformer_layer.linear2.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,837 - mmcv - INFO -
# transformer_layer.norm1.weight - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,837 - mmcv - INFO -
# transformer_layer.norm1.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,838 - mmcv - INFO -
# transformer_layer.norm2.weight - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,838 - mmcv - INFO -
# transformer_layer.norm2.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,839 - mmcv - INFO -
# anchor_projection.weight - torch.Size([64, 64, 1, 1]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,840 - mmcv - INFO -
# anchor_projection.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,840 - mmcv - INFO -
# cls_layer.0.layer.0.weight - torch.Size([640, 640]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,841 - mmcv - INFO -
# cls_layer.0.layer.0.bias - torch.Size([640]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,841 - mmcv - INFO -
# cls_layer.0.layer.2.weight - torch.Size([640, 640]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,842 - mmcv - INFO -
# cls_layer.0.layer.2.bias - torch.Size([640]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,842 - mmcv - INFO -
# cls_layer.0.layer.4.weight - torch.Size([21, 640]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,842 - mmcv - INFO -
# cls_layer.0.layer.4.bias - torch.Size([21]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,843 - mmcv - INFO -
# reg_x_layer.0.layer.0.weight - torch.Size([64, 640]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,844 - mmcv - INFO -
# reg_x_layer.0.layer.0.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,844 - mmcv - INFO -
# reg_x_layer.0.layer.2.weight - torch.Size([64, 64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,845 - mmcv - INFO -
# reg_x_layer.0.layer.2.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,845 - mmcv - INFO -
# reg_x_layer.0.layer.4.weight - torch.Size([20, 64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,846 - mmcv - INFO -
# reg_x_layer.0.layer.4.bias - torch.Size([20]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,846 - mmcv - INFO -
# reg_z_layer.0.layer.0.weight - torch.Size([64, 640]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,846 - mmcv - INFO -
# reg_z_layer.0.layer.0.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,847 - mmcv - INFO -
# reg_z_layer.0.layer.2.weight - torch.Size([64, 64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,847 - mmcv - INFO -
# reg_z_layer.0.layer.2.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,848 - mmcv - INFO -
# reg_z_layer.0.layer.4.weight - torch.Size([20, 64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,848 - mmcv - INFO -
# reg_z_layer.0.layer.4.bias - torch.Size([20]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,848 - mmcv - INFO -
# reg_vis_layer.0.layer.0.weight - torch.Size([64, 640]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,849 - mmcv - INFO -
# reg_vis_layer.0.layer.0.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,849 - mmcv - INFO -
# reg_vis_layer.0.layer.2.weight - torch.Size([64, 64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,850 - mmcv - INFO -
# reg_vis_layer.0.layer.2.bias - torch.Size([64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,850 - mmcv - INFO -
# reg_vis_layer.0.layer.4.weight - torch.Size([20, 64]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
#
# 2024-05-02 09:28:08,851 - mmcv - INFO -
# reg_vis_layer.0.layer.4.bias - torch.Size([20]):
# The value is the same before and after calling `init_weights` of Anchor3DLane
# is_resample: True
# Now loading annotations...
# after load annotation
# find 8800 samples in data/OpenLane/data_lists/training.txt.
# <All keys matched successfully>

# %%
model = TrtModel(trt_engine_path)
# Out:
# True
